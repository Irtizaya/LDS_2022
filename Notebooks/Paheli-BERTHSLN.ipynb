# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# %cd /content/drive/My\ Drive/Legal\ DS/Paheli_bert/

# %%
# !pip install -r requirements_colab.txt

# %%
import warnings
import json
import os
import string
from collections import defaultdict
import numpy as np
warnings.filterwarnings('ignore')

# %%
f = open('paheli_to_ekstep.json')
train_corpus = json.load(f)
f.close()

# %%
dev_corpus = train_corpus[-10:]
train_new = train_corpus[:40]

# %%
with open('dev_paheli_to_ekstep.json', 'w') as jsonfile:
   json.dump(dev_corpus, jsonfile)

with open('train_paheli_to_ekstep.json', 'w') as jsonfile:
   json.dump(train_new, jsonfile)

# %%
f = open('train_paheli_to_ekstep.json')
train_corpus = json.load(f)
f.close()

f = open('dev_paheli_to_ekstep.json')
dev_corpus = json.load(f)
f.close()

# %%
# !python tokenize_files.py 'train_paheli_to_ekstep.json' 'dev_paheli_to_ekstep.json' 'dev_paheli_to_ekstep.json'

# %%
# !python baseline_run.py
